# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
from sklearn.svm import LinearSVC
from sklearn.model_selection import train_test_split

df = pd.read_csv("train.csv")

#print(df.head())
#print("\nColumns:")
#print(df.columns)

#print("\nShape:")
#print(df.shape)

#print(df['toxic'].value_counts())

X = df['comment_text']
y = df['toxic']

# print(X.head())
# print()
# print(y.head())

tfidf = TfidfVectorizer(max_features=5000)

X_tfidf = tfidf.fit_transform(X)
#print(type(X_tfidf))
#print(X_tfidf.shape)

X_train, X_test, y_train, y_test = train_test_split(
    X_tfidf,
    y,
    test_size=0.2,
    random_state=42
)

# print(X_train.shape)
# print(X_test.shape)

model = LogisticRegression(max_iter=1000)
model1 = LinearSVC()

model.fit(X_train, y_train)
model1.fit(X_train, y_train)

print("Training Complete!")

y_pred = model.predict(X_test)
y_pred1 = model1.predict(X_test)

# print(y_pred[:10])

accuracy = accuracy_score(y_test, y_pred)

print("Accuracy:", accuracy)

print(classification_report(y_test, y_pred))

accuracy1 = accuracy_score(y_test, y_pred1)

print("Accuracy:", accuracy1)

print(classification_report(y_test, y_pred1))

test_sentences = [
    "Thank you for your help.",
    "Have a wonderful day.",
    "I appreciate your effort.",
    "Your presentation was very informative.",
    "I respectfully disagree with your opinion.",
    "You are an idiot.",
    "You are the dumbest person ever.",
    "What a moron.",
    "Nobody wants you here.",
    "Just get lost."
]

for sentence in test_sentences:
    vector = tfidf.transform([sentence])
    prediction = model1.predict(vector)

    label = "Toxic" if prediction[0] == 1 else "Non-Toxic"

    print(f"'{sentence}' --> {label}")
# Out:
# Training Complete!
# Accuracy: 0.9577314742284192
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.98     28859
#            1       0.91      0.62      0.74      3056
#
#     accuracy                           0.96     31915
#    macro avg       0.93      0.81      0.86     31915
# weighted avg       0.96      0.96      0.95     31915
#
# Accuracy: 0.9598934670217766
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98     28859
#            1       0.88      0.68      0.76      3056
#
#     accuracy                           0.96     31915
#    macro avg       0.92      0.83      0.87     31915
# weighted avg       0.96      0.96      0.96     31915
#
# 'Thank you for your help.' --> Non-Toxic
# 'Have a wonderful day.' --> Non-Toxic
# 'I appreciate your effort.' --> Non-Toxic
# 'Your presentation was very informative.' --> Non-Toxic
# 'I respectfully disagree with your opinion.' --> Non-Toxic
# 'You are an idiot.' --> Toxic
# 'You are the dumbest person ever.' --> Non-Toxic
# 'What a moron.' --> Toxic
# 'Nobody wants you here.' --> Non-Toxic
# 'Just get lost.' --> Non-Toxic
